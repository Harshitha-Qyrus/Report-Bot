# %%
from db_utils.db_converter import DB_SCHEMA_GENERATOR

# %%
db_schema_generator = DB_SCHEMA_GENERATOR()


database_name = "webautomation"  
# schema_result = db_schema_generator(database_name)
result = db_schema_generator(database_name=database_name)

# Print or use the result as needed
print(result)
# Out:
#  QUERYYYYYYY  SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES
#                             WHERE TABLE_SCHEMA = 'webautomation' AND TABLE_TYPE = 'BASE TABLE';
#  QUERYYYYYYY  SELECT * FROM webautomation.DATABASECHANGELOG;
#  Table: DATABASECHANGELOG
#
# First 3 rows of the table:
#                ID    AUTHOR  \
# 0  00000000000002  jhipster
#
#                                             FILENAME        DATEEXECUTED  \
# 0  config/liquibase/changelog/00000000000000_init... 2020-10-22 07:25:23
#
#    ORDEREXECUTED  EXECTYPE                              MD5SUM  \
# 0              1  EXECUTED  8:fc8e5b393c90215202ec38612ed14f68
#
#                                    DESCRIPTION COMMENTS   TAG LIQUIBASE  \
# 0  createTable tableName=jhi_date_time_wrapper           None     3.9.0
#
#   CONTEXTS LABELS DEPLOYMENT_ID
# 0     test   None    3351523756
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 14 columns):
# ...

# %%
db_schema_generator = DB_SCHEMA_GENERATOR()

database_name="webautomation" 
# schema_result = db_schema_generator(database_name)
result = db_schema_generator(database_name)

# Print or use the result as needed
print(result)
# Out:
#  QUERYYYYYYY  DESCRIBE webautomation.project
#  QUERYYYYYYY  DESCRIBE webautomation.test_suite
#  QUERYYYYYYY  DESCRIBE webautomation.test_script
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/ubuntu/Harshitha/report-bot-H/ConnectinDB.ipynb Cell 4 line 5
#       <a href='vscode-notebook-cell://ssh-remote%2Bflask/home/ubuntu/Harshitha/report-bot-H/ConnectinDB.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> database_name="webautomation"
#       <a href='vscode-notebook-cell://ssh-remote%2Bflask/home/ubuntu/Harshitha/report-bot-H/ConnectinDB.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> # schema_result = db_schema_generator(database_name)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bflask/home/ubuntu/Harshitha/report-bot-H/ConnectinDB.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> result = db_schema_generator(database_name)
# ...
